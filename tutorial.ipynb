# %%
import src.model as model
import src.dists as dists
import src.execution as execution

import os 
import sys
import numpy as np
import time
import json
from tqdm import tqdm
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Running batch simulations

# %% [markdown]
# #### Construct an environment with the required packages
# Using miniconda: https://www.anaconda.com/docs/getting-started/miniconda/main
# ```
# # Create the environment
# conda env create -f environment.yml
#
# # Activate the environment
# conda activate txns
# ```
#
# #### The batch script is `simulations.py` inside the `src/` directory
# ```
# # Run the batch script
# python src/simulations.py
#
# # The help will show you the basic arguments
# python src/simulations.py --help
#
# usage: simulations.py [-h] [--test] [--output-dir OUTPUT_DIR] [--seed SEED]
#                       [--seed-setup SEED_SETUP] [--seed-run SEED_RUN]
#
# Run a batch of transaction simulations.
#
# options:
#   -h, --help            show this help message and exit
#   --test                Run in test mode (default: False)
#   --output-dir OUTPUT_DIR
#                         Output directory for results
#   --seed SEED           Master seed; each combination gets a derived
#                         (seed_setup, seed_run) pair.
#   --seed-setup SEED_SETUP
#                         Pin the setup seed (population draw) across every
#                         combination.
#   --seed-run SEED_RUN   Pin the run seed (transaction realization) across
#                         every combination.
# ```

# %% [markdown]
# ## Setting up a batch
# ### Many arguments are specified in the batch simulator `simulate.py`.

# %%
# For this notebook, define the output directories here not inline
projdir = os.path.abspath(os.getcwd())
simsdir = os.path.join(projdir, 'output')

# For the tutorial, we will run in test mode
test = True

# It is possible to set a random seed for reproducibility
seed = 42

# %% [markdown]
# #### This cell defines constants and default values used throughout the simulation

# %%
rng = np.random.default_rng(seed=42)  # used only for ad-hoc draws in this notebook; the simulator uses per-combination setup/run RNGs.

SIZE_SCALE = 1  # Scale factor for the number of agents
LENGTH_SCALE = 6  # Scale factor for the number of transactions
MEAN_IET = 43706315  # Actually, total time in seconds, not IET. 43706315 seconds =  1 Sarafu time unit (About 1 yr and a half)

N = 25_000 // SIZE_SCALE  # Number of agents
T = int(500_000 * LENGTH_SCALE)  # Total number of transactions. 500_00 is about the number we have in sarafu dataset (a bit more)
saved = 500_000  # Number of iterations to save

# %% [markdown]
# #### Enable Test Mode for Quick Debugging
#
# If the test flag is active, smaller values are used for faster iteration and debugging.

# %%
if test:
    N = 500
    T = 50
    saved = 20

print(f"Iteration : {T:_}")
print(f"Save : {saved:_}")
# Out:
# Iteration : 50
# Save : 20

# %% [markdown]
# ### Define All Distributions for Agent Behavior
#
# In this step, we define all key statistical behaviors for agents using named distributions:
#
# - **Spending Rate**: Probability of spending per agent.
# - **Initial Balance**: Starting funds for each agent.
# - **Activity**: Likelihood to initiate a transaction.
# - **Attractivity**: Likelihood to be selected as a recipient.
# - **Copula**: Joint distribution capturing dependency between activity and attractivity.
#
# Each is represented by:
# - A name
# - Parameters
# - A lambda function for value generation

# %%
# Generators take (N, rng) so each call uses the per-simulation setup_rng.
spending_rate_list = [
    ("uniform", [0, 1], lambda N, rng: rng.uniform(1e-16, 1, N)),
    # ("beta", [0.4, 0.6], lambda N, rng: rng.beta(0.4, 0.6, N)),
]

# Initial balances
initial_bal_list = [
    ("constant", [1000], lambda N, rng: 1000 * np.ones(N)),
    # ("uniform", [0, 2000], lambda N, rng: rng.uniform(1e-16, 2000, N)),
]

# Activity distribution
activity_distributions = [
    ("powlaw", [1.85, 1, 1838], lambda unif: dists.powlaw_ppf(1.85, 1, 1838)(unif)),
]

# Attractivity distribution
attractivity_distributions = [
    ("powlaw", [1.87, 1, 2118], lambda unif: dists.powlaw_ppf(1.87, 1, 2118)(unif)),
]

# Copula for joint distribution of activity and attractivity
copulas = [
    ('joe', 3.15, False),
    # ('joe', 1, False),
]

# %% [markdown]
# ### Define the remaining parameters
#
# We use lists, always. When we use the same value over all the simulations we use a single valued list

# %%
betabinomial_xi = [1, 2, 3, 5, None]  # Scale parameters for beta-binomial behavior
burstiness = [0.25, 1]             # Temporal clustering of activity
decimals = [3]                     # Decimal precision for numerical values

# %% [markdown]
# ### Define the Simulation Parameter Grid
#
# Here, we organize all simulation parameters into a dictionary. Each key maps to a list of values that will be used to create all combinations of parameter settings.
#
# This parameter grid drives the batch simulations by specifying:
# - Agent and environment properties
# - Behavioral distribution types
# - Simulation scales and precision

# %%
parameter_dict = {
    "xi": betabinomial_xi,  # List of scaling values (always use list)
    "spending_rate": spending_rate_list,
    "initial_balance": initial_bal_list,
    "decimals": decimals, # Decimal precision for balances
    "copula": copulas,
    "activity_distribution": activity_distributions,
    "attractivity_distribution": attractivity_distributions,
    "N": [N],  # Number of agents
    "T": [T],  # Total time steps
    "SIZE_SCALE": [SIZE_SCALE],
    "LENGTH_SCALE": [LENGTH_SCALE],
    "MEAN_IET": [MEAN_IET],
    "burstiness": burstiness,  # Activity burst levels
}

# %% [markdown]
# ### Create Output Directory
#
# This step sets the output directory based on whether test mode is enabled. It ensures the directory exists before running simulations.
#
# If not in test mode, the script pauses for confirmation to avoid accidental writes.

# %%
continue_running = 'y'  # Automatically proceed (no prompt)

if continue_running == 'n':
    print('Please create the output directory')
    exit()

# Choose output path based on test mode
output_dir = (
    os.path.join(simsdir, 'test') if test else os.path.join(simsdir)
)

if not test:
    print(output_dir)
    input('Continue?')  # Pause for confirmation in full run mode

# Ensure the directory exists
os.makedirs(output_dir, exist_ok=True)

# %% [markdown]
# ### Generate Parameter Grid and Run Simulations
#
# In this final step:
#
# 1. We generate all combinations of the parameter settings using `create_parameter_grid`.
# 2. We pass this grid to the batch runner along with:
#    - The number of transactions to save.
#    - The output directory path.
#
# This will launch the full set of simulations using the specified agent behaviors and environment settings.

# %%
# Create all combinations of parameters
# If a seed is provided, it will be used to generate seeds for each simulation
parameter_grid = execution.create_parameter_grid(parameter_dict,seed=seed)

# Run batch simulations using the generated grid
execution.batch_runner(parameter_grid, output_dir, saved=saved)
# Out:
# Batch Simulations:  10%|█         | 1/10 [00:00<00:01,  8.81it/s]
# Completed simulation: {'xi': 1, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 0.25, 'seed_setup': np.int64(383329927), 'seed_run': np.int64(2261209995)}
# Execution time: 0.02 seconds
# End of 0: 237.89 MB (Resident Set Size)
# Memory cleared.
# Completed simulation: {'xi': 1, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 1, 'seed_setup': np.int64(3324115916), 'seed_run': np.int64(4190266092)}
# Execution time: 0.01 seconds
# End of 1: 240.14 MB (Resident Set Size)
# Batch Simulations:  40%|████      | 4/10 [00:00<00:00, 16.54it/s]
# Memory cleared.
# Completed simulation: {'xi': 2, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 0.25, 'seed_setup': np.int64(2811363264), 'seed_run': np.int64(3160032368)}
# Execution time: 0.01 seconds
# End of 2: 242.19 MB (Resident Set Size)
# Memory cleared.
# Completed simulation: {'xi': 2, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 1, 'seed_setup': np.int64(1884968544), 'seed_run': np.int64(3269070126)}
# Execution time: 0.01 seconds
# End of 3: 244.25 MB (Resident Set Size)
# Memory cleared.
# Completed simulation: {'xi': 3, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 0.25, 'seed_setup': np.int64(1859786275), 'seed_run': np.int64(3081541439)}
# Execution time: 0.01 seconds
# End of 4: 246.34 MB (Resident Set Size)
# Memory cleared.
# Completed simulation: {'xi': 3, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 1, 'seed_setup': np.int64(3687649985), 'seed_run': np.int64(3376120482)}
# Execution time: 0.01 seconds
# End of 5: 248.27 MB (Resident Set Size)
# Memory cleared.
# Completed simulation: {'xi': 5, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 0.25, 'seed_setup': np.int64(369133708), 'seed_run': np.int64(2204291346)}
# Execution time: 0.01 seconds
# End of 6: 250.20 MB (Resident Set Size)
# Batch Simulations: 100%|██████████| 10/10 [00:00<00:00, 18.31it/s]
# Memory cleared.
# Completed simulation: {'xi': 5, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 1, 'seed_setup': np.int64(2995172877), 'seed_run': np.int64(550243861)}
# Execution time: 0.01 seconds
# End of 7: 250.25 MB (Resident Set Size)
# Memory cleared.
# Completed simulation: {'xi': None, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 0.25, 'seed_setup': np.int64(865305066), 'seed_run': np.int64(3606691181)}
# Execution time: 0.01 seconds
# End of 8: 250.25 MB (Resident Set Size)
# Memory cleared.
# Completed simulation: {'xi': None, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 1, 'seed_setup': np.int64(404488628), 'seed_run': np.int64(1934392872)}
# Execution time: 0.01 seconds
# End of 9: 250.39 MB (Resident Set Size)
# Memory cleared.
# All simulations completed.
# Total execution time: 0.65 seconds

# %% [markdown]
# # 1.a Inside the `batch_runner()`

# %%
# Start the timer for the entire loop
loop_start = time.time()

# Initialize empty list to track memory usage
memory = []

# Define file path for metadata summary
metadata_file = os.path.join(output_dir, "metadata_summary.json")

# Initialize empty list to track metadata summary
metadata_summary = []

# %% [markdown]
# ## The main loop

# %%
# Iterate over each set of parameters
for idx, params in enumerate(tqdm(parameter_grid, desc="Batch Simulations")):
    try:
        # If the number of transactions to save was not specified,
        # use the value from the current parameter set
        if saved is None:
            saved = params['T']

        # Generate unique identifier for simulation
        simulation_id = f'{idx}'
        time_id = f'{int(time.time())}'

        # Run the simulation
        transactions_df, metadata, execution_time, nodes_df = execution.run_simulation(params, saved=saved)

        # Add simulation ID to metadata
        metadata["simulation_id"] = simulation_id

        # Save transactions
        transaction_file = os.path.join(output_dir, f"{simulation_id}.parquet")
        transactions_df.to_parquet(transaction_file, index=False)

        nodes_file = os.path.join(output_dir, f'nodes_{simulation_id}.csv')
        nodes_df.to_csv(nodes_file, index=False)

        # Save metadata for this simulation
        metadata_file_path = os.path.join(output_dir, f"{simulation_id}_metadata.json")
        with open(metadata_file_path, 'w') as f:
            json.dump(execution.convert_metadata_to_serializable(metadata), f, indent=4)

        # Track metadata summary
        metadata_summary.append({
            "simulation_id": simulation_id,
            "transaction_file": transaction_file,
            "metadata_file": metadata_file_path,
            "time id": time_id,
            "execution_time": execution_time,
        })

        print(f"Completed simulation: {params}")
        print(f"Execution time: {execution_time:.2f} seconds")
        memory.append(execution.print_memory_usage(f"End of {simulation_id}"))

        # Clear memory after each loop
        execution.clear_memory()

    except Exception as e:
        print(f"Error in simulation {idx}: {e}")
        continue
# Out:
# Batch Simulations:  30%|███       | 3/10 [00:00<00:00, 20.41it/s]
# Completed simulation: {'xi': 1, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 0.25, 'seed_setup': np.int64(383329927), 'seed_run': np.int64(2261209995)}
# Execution time: 0.01 seconds
# End of 0: 256.03 MB (Resident Set Size)
# Memory cleared.
# Completed simulation: {'xi': 1, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 1, 'seed_setup': np.int64(3324115916), 'seed_run': np.int64(4190266092)}
# Execution time: 0.01 seconds
# End of 1: 256.09 MB (Resident Set Size)
# Memory cleared.
# Completed simulation: {'xi': 2, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 0.25, 'seed_setup': np.int64(2811363264), 'seed_run': np.int64(3160032368)}
# Execution time: 0.01 seconds
# End of 2: 256.16 MB (Resident Set Size)
# Memory cleared.
# Completed simulation: {'xi': 2, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 1, 'seed_setup': np.int64(1884968544), 'seed_run': np.int64(3269070126)}
# Execution time: 0.01 seconds
# End of 3: 256.16 MB (Resident Set Size)
# Memory cleared.
# Completed simulation: {'xi': 3, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 0.25, 'seed_setup': np.int64(1859786275), 'seed_run': np.int64(3081541439)}
# Execution time: 0.01 seconds
# End of 4: 256.16 MB (Resident Set Size)
# Memory cleared.
# Batch Simulations:  90%|█████████ | 9/10 [00:00<00:00, 20.79it/s]
# Completed simulation: {'xi': 3, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 1, 'seed_setup': np.int64(3687649985), 'seed_run': np.int64(3376120482)}
# Execution time: 0.01 seconds
# End of 5: 256.27 MB (Resident Set Size)
# Memory cleared.
# Completed simulation: {'xi': 5, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 0.25, 'seed_setup': np.int64(369133708), 'seed_run': np.int64(2204291346)}
# Execution time: 0.01 seconds
# End of 6: 256.27 MB (Resident Set Size)
# Memory cleared.
# Completed simulation: {'xi': 5, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 1, 'seed_setup': np.int64(2995172877), 'seed_run': np.int64(550243861)}
# Execution time: 0.01 seconds
# End of 7: 256.27 MB (Resident Set Size)
# Memory cleared.
# Completed simulation: {'xi': None, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 0.25, 'seed_setup': np.int64(865305066), 'seed_run': np.int64(3606691181)}
# Execution time: 0.01 seconds
# End of 8: 256.27 MB (Resident Set Size)
# Memory cleared.
# Batch Simulations: 100%|██████████| 10/10 [00:00<00:00, 20.68it/s]
# Completed simulation: {'xi': None, 'spending_rate': ('uniform', [0, 1], <function <lambda> at 0x1794b9d00>), 'initial_balance': ('constant', [1000], <function <lambda> at 0x1794b9c60>), 'decimals': 3, 'copula': ('joe', 3.15, False), 'activity_distribution': ('powlaw', [1.85, 1, 1838], <function <lambda> at 0x1794b9da0>), 'attractivity_distribution': ('powlaw', [1.87, 1, 2118], <function <lambda> at 0x1794b9e40>), 'N': 500, 'T': 50, 'SIZE_SCALE': 1, 'LENGTH_SCALE': 6, 'MEAN_IET': 43706315, 'burstiness': 1, 'seed_setup': np.int64(404488628), 'seed_run': np.int64(1934392872)}
# Execution time: 0.01 seconds
# End of 9: 256.27 MB (Resident Set Size)
# Memory cleared.

# %% [markdown]
# Last steps:
# - save metadata and report total execution time
# - show how `build_target_sampler` storage scales with N, and where it drops once N exceeds `matrix_n_threshold`

# %%
# Save metadata summary
with open(metadata_file, 'w') as f:
    json.dump(metadata_summary, f, indent=4)

print("All simulations completed.")
print(f"Total execution time: {time.time() - loop_start:.2f} seconds")

# Sampler storage vs N. At or below `matrix_n_threshold`, build_target_sampler
# precomputes an (N, N) cumulative-row matrix (O(N^2) memory). Above it, it falls
# back to a shared (N,) cumulative attractivity vector with rejection sampling
# (O(N) memory). We sweep N across a low demo threshold so the drop is visible
# without allocating gigabytes; the package default is matrix_n_threshold=20_000.
import gc
demo_threshold = 2_000
ns = [200, 500, 1000, 1500, 1900, 1999, 2001, 2500, 3000, 4000, 5000]
sizes_mb = []
for N_ in ns:
    nodes_ = model.create_nodes(N_, activity=np.ones(N_), attractivity=np.ones(N_))
    sampler_ = model.build_target_sampler(nodes_, matrix_n_threshold=demo_threshold)
    sizes_mb.append(sampler_.data.nbytes / 1e6)
    del nodes_, sampler_
    gc.collect()

plt.figure()
plt.plot(ns, sizes_mb, marker='o')
plt.axvline(demo_threshold, ls='--', color='gray',
            label=f'matrix_n_threshold = {demo_threshold:,} (demo; default 20,000)')
plt.xlabel('N (number of nodes)')
plt.ylabel('TargetSampler.data (MB)')
plt.title('Sampler storage: O(N²) at or below threshold, O(N) above')
plt.legend()
plt.grid(True, alpha=0.3)
plt.savefig(os.path.join(output_dir, "sampler_memory_vs_N.png"))
plt.show()
# Out:
# All simulations completed.
# Total execution time: 0.50 seconds

# %% [markdown]
# # 2. A single simulation
#
# ### Now let's look at how a single run works

# %%
#first start the chronometer
start_time = time.time()

# %% [markdown]
# ## Extracting Simulation Parameters
#
# We load all the basic scalar values needed for the simulation from the `params` dictionary.
# These include number of nodes, time steps, decimal precision, and other core settings that define how the simulation behaves.
#
#
# The `params` dictionary is expected to contain the following keys and value types:
#
# ```
# params = {
#     'seed_setup': int,  # Seed for the population draw (h(s), activity, attractivity, initial balances)
#     'seed_run': int,    # Seed for the realization (first activations + the transact() loop)
#     'xi': float,        # Beta-Binomial precision parameter (paper's ξ)
#
#     'spending_rate': (
#         str,             # Type name of the distribution (e.g., 'uniform')
#         list[float],     # Parameters for the distribution
#         Callable[[int], np.ndarray]  # Function that generates N values
#     ),
#
#     'initial_balance': (
#         str,             # Type name of the distribution (e.g., 'constant')
#         list[float],     # Parameters for the distribution
#         Callable[[int], np.ndarray]  # Function that generates N values
#     ),
#
#     'decimals': int,  # Number of decimal places for balances
#
#     'copula': (
#         str,     # Copula type (e.g., 'joe', 'gumbel', etc.)
#         float,   # Parameter for the copula
#         bool     # Whether to reverse the copula dependency
#     ),
#
#     'activity_distribution': (
#         str,             # Distribution type (e.g., 'powlaw')
#         list[float],     # Parameters for the distribution
#         Callable[[np.ndarray], np.ndarray]  # Generator function
#     ),
#
#     'attractivity_distribution': (
#         str,             # Distribution type (e.g., 'powlaw')
#         list[float],     # Parameters for the distribution
#         Callable[[np.ndarray], np.ndarray]  # Generator function
#     ),
#
#     'N': int,  # Number of nodes (agents) in the simulation
#     'T': int,  # Number of simulation steps (total transactions)
#
#     'SIZE_SCALE': float,    # Scaling factor for transaction size
#     'LENGTH_SCALE': float,  # Scaling factor for transaction length/duration
#     'MEAN_IET': float,      # Mean inter-event time
#     'burstiness': float     # Burstiness parameter (controls temporal irregularity)
# }

# %%
# Extract scalar parameters from the input dictionary
params = parameter_grid[0] # we are using one from the parameter_grid, we can define it from scratch if we want
seed_setup = params["seed_setup"]
seed_run = params["seed_run"]
xi = params["xi"]
decimals = params["decimals"]
N = params["N"]
T = params["T"]
SIZE_SCALE = params["SIZE_SCALE"]
LENGTH_SCALE = params["LENGTH_SCALE"]
MEAN_IET = params["MEAN_IET"]
burstiness = params["burstiness"]

# Two independent RNGs: setup draws the population, run draws the realization.
setup_rng = np.random.default_rng(seed_setup)
run_rng = np.random.default_rng(seed_run)

# %% [markdown]
# ### Now we extract metadata (name and parameters) of the distributions, and the actual random number generators

# %%
# Extract distributions and generators
sprate_type, sprate_params, sprate_generator = params["spending_rate"]
inbal_type, inbal_params, inbal_generator = params["initial_balance"]
copula_type, copula_param, reversed_copula = params["copula"]
activity_type, activity_params, activity_generator = params["activity_distribution"]
attractivity_type, attractivity_params, attractivity_generator = params["attractivity_distribution"]

# %% [markdown]
# Generate the actual "Activity" and "Attractiveness" parameters, the expected number of transaction in the given time span "MEAN_IET". As well we generate the initial balances and spending rate parameters.

# %%
# Generate activity and attractivity vectors
vect_act, vect_att = execution.generate_activity_attractivity(
    N=N,
    copula_type=copula_type,
    copula_param=copula_param,
    reversed_copula=reversed_copula,
    activity_generator=activity_generator,
    attractivity_generator=attractivity_generator,
    rng=setup_rng,
)


# Generate spending rates and initial balances
spending_rate = sprate_generator(N, setup_rng)
initial_bal = inbal_generator(N, setup_rng)

# %% [markdown]
# Now we create the nodes, the transition matrix, we assign the parameters etc

# %%
# Initialize the model
nodes = model.create_nodes(
    N, activity=vect_act, attractivity=vect_att,
    spending=spending_rate, mean_iet=MEAN_IET, burstiness=burstiness
)
transitions = model.build_target_sampler(nodes)
activations = model.initialize_activations(nodes, rng=run_rng)
balances = model.initialize_balances(nodes, balances=initial_bal, decimals=decimals)

# %% [markdown]
# The main loop and some saving steps

# %%
# Prepare to write transactions
header = ["timestamp", "source", "target", "amount", "source_bal", "target_bal"]

if saved is None:
    saved = params['T']
transactions_list = [None] * saved
burn_in_period = T - saved

# Run the model
for i in range(T):
    transaction = model.transact(nodes, activations, transitions, balances, xi=xi, rng=run_rng)
    if i >= burn_in_period:
        transactions_list[i-burn_in_period] = [transaction[term] for term in header]
